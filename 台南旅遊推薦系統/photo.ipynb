# %%
import os
import pandas as pd


path = '/Users/Jerry/Desktop/台南景點照片'



#檔案夾中所有檔案名字
filelist = os.listdir(path)
#print(filelist)


#景點分類
pointType = pd.read_excel('/Users/Jerry/Desktop/type.xlsx', usecols=['景點名稱','Tag'])
pointType
# Out:
#           景點名稱  Tag
# 0       四草綠色隧道  第9組
# 1         安平古堡  第8組
# 2       德元埤荷蘭村  第3組
# 3      井仔腳瓦盤鹽田  第9組
# 4          神農街  第2組
# ..         ...  ...
# 535   八吉境道署關帝廳  第4組
# 536        三角湧  第2組
# 537  篤加聚落文物展覽館  第9組
# 538  梅嶺神祕氣場露營區  第7組
# 539      飛虎將軍廟  第1組
#
# [540 rows x 2 columns]

# %%
# 1
filter1 = pointType['Tag']== "第1組"
Type1 = pointType[filter1]

# 2
filter2 = pointType['Tag']== "第2組"
Type2 = pointType[filter2]

# 3
filter3 = pointType['Tag']== "第3組"
Type3 = pointType[filter3]

# 4
filter4 = pointType['Tag']== "第4組"
Type4 = pointType[filter4]

# 5
filter5 = pointType['Tag']== "第5組"
Type5 = pointType[filter5]

# 6
filter6 = pointType['Tag']== "第6組"
Type6 = pointType[filter6]

# 7
filter7 = pointType['Tag']== "第7組"
Type7 = pointType[filter7]

# 8
filter8 = pointType['Tag']== "第8組"
Type8 = pointType[filter8]

# 9
filter9 = pointType['Tag']== "第9組"
Type9 = pointType[filter9]

# %%
# 第一類景點 
type1List= []
for i in Type1['景點名稱']:
    type1List.append(i)
print(type1List)

# 第二類景點 
type2List= []
for i in Type2['景點名稱']:
    type2List.append(i)
print(type2List)

# 第三類景點 
type3List= []
for i in Type3['景點名稱']:
    type3List.append(i)
print(type3List)

# 第四類景點 
type4List= []
for i in Type4['景點名稱']:
    type4List.append(i)
print(type4List)

# 第五類景點 
type5List= []
for i in Type5['景點名稱']:
    type5List.append(i)
print(type5List)

# 第六類景點 
type6List= []
for i in Type6['景點名稱']:
    type6List.append(i)
print(type6List)

# 第七類景點 
type7List= []
for i in Type7['景點名稱']:
    type7List.append(i)
print(type7List)

# 第八類景點 
type8List= []
for i in Type8['景點名稱']:
    type8List.append(i)
print(type8List)

# 第九類景點 
type9List= []
for i in Type9['景點名稱']:
    type9List.append(i)
print(type9List)
# Out:
# ['國立臺灣歷史博物館', '港濱歷史公園', '巴克禮公園', '八田與一紀念園區', '北門水晶教堂', '原林百貨', '台灣詩路', '玉山寶光聖堂', '原台南州廳-台灣文學館', '台灣烏腳病醫療紀念館', '鄭成功文物館', '原台南合同廳舍(消防史料館)', '土地銀行台南分行(原日本勸業銀行台南支店)', '臺南神學院(原台南神學校校舍暨禮拜堂)', '隱田山房(白色教堂)', '台南文化創意產業園區', '方圓美術館', '竹溪寺', '開元寺', '總爺藝文中心', '臺灣Holocaust和平紀念館(車路墘教會)', '看西街教會', '湯德章紀念公園', '竹門綠色隧道', '洪通故居彩繪村', '東嶽殿', '鶯料理(鷲嶺食肆)', '吉貝耍平埔文化園區', '拔馬平埔文物館', '顏水龍紀念公園', '太平境馬雅各紀念教會', '南一中紅樓及小禮堂(原台南州立第二中學校校舍本館暨講堂)', '雲嘉南濱海國家風景區管理處', '永康車站', '東山農會咖啡文化館', '龍船窩', '東隆宮文化中心', '接官亭', '東安坊文化園區', '凌波吊橋', '臺灣府城巽方砲臺(巽方靖鎮)', '鹽分地帶文化館-香雨書院', '龍山寺', '國立台南大學紅樓', '大社東勢北極殿', '原臺南州立農事試驗場宿舍群及辦公廳舍', '成功大學舊文學院及大成館(原日軍步兵第二聯隊營舍)', '吳晉淮音樂紀念館', '王姓大宗祠', '成功大學禮賢樓(原日軍步兵第二聯隊本部)', '長榮中學校史館、校牧館(原台南長老教中學校講堂暨校長宿舍)', '北門嶼教會', '菁寮國小', '長榮女中長榮大樓', '永康社教中心', 'B.B.ART', '新安宮藝文中心', '林崑岡紀念館', '重道崇文坊', '擇賢堂', '羅來受教會', '台南二中(原台南中學學校講堂)', '東門巴克禮教會', '臺南市原住民文物館', '原安平陳保正厝', '飛虎將軍廟']
# ...

# %%
import shutil

for i in filelist:
    source = '/Users/Jerry/Desktop/台南景點照片/{}'.format(i)
    
    if i in type1List:
        destination = '/Users/Jerry/Desktop/分類/Type1'
        shutil.move(source,destination)

    if i in type2List:
        destination = '/Users/Jerry/Desktop/分類/Type2'
        shutil.move(source,destination)

    if i in type3List:
        destination = '/Users/Jerry/Desktop/分類/Type3'
        shutil.move(source,destination)
    
    if i in type4List:
        destination = '/Users/Jerry/Desktop/分類/Type4'
        shutil.move(source,destination)

    if i in type5List:
        destination = '/Users/Jerry/Desktop/分類/Type5'
        shutil.move(source,destination)

    if i in type6List:
        destination = '/Users/Jerry/Desktop/分類/Type6'
        shutil.move(source,destination)

    if i in type7List:
        destination = '/Users/Jerry/Desktop/分類/Type7'
        shutil.move(source,destination)

    if i in type8List:
        destination = '/Users/Jerry/Desktop/分類/Type8'
        shutil.move(source,destination)

    if i in type9List:
        destination = '/Users/Jerry/Desktop/分類/Type9'
        shutil.move(source,destination)

# %%
Type1list = os.listdir('/Users/Jerry/Desktop/專題網頁/static/分類/Type1')
Type2list = os.listdir('/Users/Jerry/Desktop/專題網頁/static/分類/Type2')
Type3list = os.listdir('/Users/Jerry/Desktop/專題網頁/static/分類/Type3')
Type4list = os.listdir('/Users/Jerry/Desktop/專題網頁/static/分類/Type4')
Type5list = os.listdir('/Users/Jerry/Desktop/專題網頁/static/分類/Type5')
Type6list = os.listdir('/Users/Jerry/Desktop/專題網頁/static/分類/Type6')
Type7list = os.listdir('/Users/Jerry/Desktop/專題網頁/static/分類/Type7')
Type8list = os.listdir('/Users/Jerry/Desktop/專題網頁/static/分類/Type8')
Type9list = os.listdir('/Users/Jerry/Desktop/專題網頁/static/分類/Type9')

# %%
values = ['Type1list', 'Type2list', 'Type3list']
# Out:
# ['雲嘉南濱海國家風景區管理處',
#  '玉山寶光聖堂',
#  '原臺南州立農事試驗場宿舍群及辦公廳舍',
#  '台南二中(原台南中學學校講堂)',
#  '菁寮國小',
#  '台南文化創意產業園區',
#  '竹溪寺',
#  '國立台南大學紅樓',
#  '成功大學舊文學院及大成館(原日軍步兵第二聯隊營舍)',
#  '拔馬平埔文物館',
#  '洪通故居彩繪村',
#  '隱田山房(白色教堂)',
#  '新安宮藝文中心',
#  '吳晉淮音樂紀念館',
#  '北門水晶教堂',
#  '林崑岡紀念館',
#  '看西街教會',
#  '長榮女中長榮大樓',
#  '擇賢堂',
#  '土地銀行台南分行(原日本勸業銀行台南支店)',
#  '吉貝耍平埔文化園區',
#  '台灣詩路',
#  '顏水龍紀念公園',
#  '成功大學禮賢樓(原日軍步兵第二聯隊本部)',
#  '鹽分地帶文化館-香雨書院',
#  '王姓大宗祠',
#  '凌波吊橋',
#  '龍山寺',
#  '原台南合同廳舍(消防史料館)',
#  '鄭成功文物館',
#  '大社東勢北極殿',
#  '長榮中學校史館、校牧館(原台南長老教中學校講堂暨校長宿舍)',
#  '東山農會咖啡文化館',
#  '東隆宮文化中心',
#  '臺南神學院(原台南神學校校舍暨禮拜堂)',
#  '永康車站',
#  '臺灣府城巽方砲臺(巽方靖鎮)',
#  '東安坊文化園區',
#  '原台南州廳-台灣文學館',
#  '方圓美術館',
#  '南一中紅樓及小禮堂(原台南州立第二中學校校舍本館暨講堂)',
#  '東嶽殿',
#  '港濱歷史公園',
#  '重道崇文坊',
#  '八田與一紀念園區',
#  '臺灣Holocaust和平紀念館(車路墘教會)',
#  '鶯料理(鷲嶺食肆)',
#  '東門巴克禮教會',
#  '接官亭',
#  '原林百貨',
#  'B.B.ART',
#  '北門嶼教會',
#  '巴克禮公園',
#  '總爺藝文中心',
#  '湯德章紀念公園',
#  '開元寺',
#  '龍船窩',
#  '羅來受教會',
#  '永康社教中心',
#  '飛虎將軍廟',
#  '太平境馬雅各紀念教會',
#  '國立臺灣歷史博物館',
# ...

# %%
import pandas as pd

total_place = pd.read_excel('/Users/Jerry/Desktop/專題網頁/all_comments.xlsx', usecols=['地點'])
for i in total_place['地點']:
    print(i)
# Out:
# 湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# 天鵝湖公園(舊名埤寮埤)
# ...

# %%
pivot_table_list = []
for i in total_place['地點']:
    if i not in pivot_table_list:
        pivot_table_list.append(i)

# %%
len(pivot_table_list)
# Out:
# 401

# %%
import shutil

one = '/Users/Jerry/Desktop/專題網頁/static/分類/Type9list'
oneList = os.listdir(one)
for i in oneList:
    if i not in pivot_table_list:
        source = '/Users/Jerry/Desktop/專題網頁/static/分類/Type9list/{}'.format(i)
        destination = '/Users/Jerry/Desktop/專題網頁/static/分類/delete'
        shutil.move(source,destination)

# %%
from restaurant import resrecommand

result = resrecommand('安平觀音亭')

if result =='附近暫無推薦餐廳':
    judge1 = False
else:
    judge1 = True
print(judge1)
# Out:
# True

# %%
a = ['a','b','c','d','e']

points = ''
for i in a[1:-1]:
    points = points + i + '|'
points
# Out:
# 'b|c|d|'
